# %% [markdown]
# ## 순차 검색

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/Othercomputers/내 노트북/study/06_TextAnalytics/data/neurips.csv')
df.head()
# Out:
#    year                                              title  \
# 0  2007                        Competition Adds Complexity
# 1  2007  Efficient Principled Learning of Thin Junction...
# 2  2007     Regularized Boost for Semi-Supervised Learning
# 3  2007  Simplified Rules and Theoretical Analysis for ...
# 4  2007  Predicting human gaze using low-level saliency...
#
#                                             abstract
# 0  It is known that determinining whether a DEC-P...
# 1  We present the first truly polynomial algorith...
# 2  Semi-supervised inductive learning concerns ho...
# 3  We show that under suitable assumptions (prima...
# 4  Under natural viewing conditions, human observ...

# %%
query = {'natural', 'language'}

import re
def tokenize(text):
    text = text.lower() # 소문자로 변환
    return re.findall(r'\w{2,}', text) # 2글자 이상 단어 추출

# %% [markdown]
# ### 표의 각 행에서 순서대로 검색어가 있는지 확인

# %%
# %%time
results = []
for row in df.itertuples():
    words = set(tokenize(row.abstract))
    if query < words: # 검색어가 부분집합이면
        results.append(row.Index)
# Out:
# CPU times: user 231 ms, sys: 0 ns, total: 231 ms
# Wall time: 230 ms

# %% [markdown]
# ### 조건에 맞는 행 번호

# %%
results
# Out:
# [49,
#  269,
#  542,
#  557,
#  846,
#  881,
#  1068,
#  1079,
#  1219,
#  1278,
#  1503,
#  1660,
#  1805,
#  1911,
#  1917,
#  1961,
#  1980,
#  2047,
#  2138,
#  2186,
#  2187,
#  2284,
#  2393,
#  2412,
#  2516,
#  2544,
#  2581,
#  2682,
#  2700,
#  2770,
#  2864,
#  2897,
#  2900,
#  2920,
#  2931,
#  3148,
#  3266,
#  3303,
#  3333,
#  3445,
#  3543,
#  3640,
#  3727,
#  3844,
#  3878,
#  3883]

# %% [markdown]
# ### 조건에 맞는 행 보기

# %%
df.loc[results]
# Out:
#       year                                              title  \
# 49    2007  Discriminative Keyword Selection Using Support...
# 269   2008  Modeling the effects of memory on human online...
# 542   2009                  Rethinking LDA: Why Priors Matter
# 557   2009                          Conditional Neural Fields
# 846   2010      Probabilistic Deterministic Infinite Automata
# 881   2011  Inverting Grice's Maxims to Learn Rules from N...
# 1068  2011  Kernel Embeddings of Latent Tree Graphical Models
# 1079  2011  Higher-Order Correlation Clustering for Image ...
# 1219  2012  Learned Prioritization for Trading Off Accurac...
# 1278  2012  Tensor Decomposition for Fast Parsing with Lat...
# 1503  2013  Unsupervised Spectral Learning of Finite State...
# 1660  2013       A Deep Architecture for Matching Short Texts
# 1805  2013  A Novel Two-Step Method for Cross Language Rep...
# 1911  2014            Global Belief Recursive Neural Networks
# 1917  2014  Deep Fragment Embeddings for Bidirectional Ima...
# 1961  2014  Submodular meets Structured: Finding Diverse S...
# 1980  2014  Conditional Random Field Autoencoders for Unsu...
# 2047  2014  A Multi-World Approach to Question Answering a...
# 2138  2014  Altitude Training: Strong Bounds for Single-La...
# 2186  2014  Convolutional Neural Network Architectures for...
# 2187  2014  Deep Recursive Neural Networks for Composition...
# 2284  2015        Learning to Transduce with Unbounded Memory
# 2393  2015  Rapidly Mixing Gibbs Sampling for a Class of F...
# 2412  2015  Expressing an Image Stream with a Sequence of ...
# 2516  2015  A Structural Smoothing Framework For Robust Gr...
# 2544  2015       Testing Closeness With Unequal Sized Samples
# 2581  2015           Teaching Machines to Read and Comprehend
# 2682  2016                           Value Iteration Networks
# 2700  2016              End-to-End Goal-Driven Web Navigation
# 2770  2016  Stochastic Structured Prediction under Bandit ...
# 2864  2016  Man is to Computer Programmer as Woman is to H...
# 2897  2016  Visual Question Answering with Question Repres...
# 2900  2016                     Dialog-based Language Learning
# 2920  2016     Latent Attention For If-Then Program Synthesis
# 2931  2016               Can Active Memory Replace Attention?
# 3148  2016  LightRNN: Memory and Computation-Efficient Rec...
# 3266  2017  Cortical microcircuits as gated-recurrent neur...
# 3303  2017   Avoiding Discrimination through Causal Reasoning
# 3333  2017                   Self-Normalizing Neural Networks
# 3445  2017  Emergence of Language with Multi-agent Games: ...
# 3543  2017        Adversarial Ranking for Language Generation
# 3640  2017  Deconvolutional Paragraph Representation Learning
# 3727  2017  Teaching Machines to Describe Images with Natu...
# 3844  2017  Learned in Translation: Contextualized Word Ve...
# 3878  2017  The power of absolute discounting: all-dimensi...
# 3883  2017  Z-Forcing: Training Stochastic Recurrent Networks
#
#                                                abstract
# 49    Many tasks in speech processing involve classi...
# 269   Language comprehension in humans is significan...
# 542   Implementations of topic models typically use ...
# 557   Conditional random fields (CRF) are quite succ...
# 846   We propose a novel Bayesian nonparametric appr...
# 881   We consider the problem of learning rules from...
# 1068  Latent tree graphical models are natural tools...
# 1079  For many of the state-of-the-art computer visi...
# 1219  Users want natural language processing (NLP) s...
# 1278  We describe an approach to speed-up inference ...
# 1503  Finite-State Transducers (FST) are a standard ...
# 1660  Many machine learning problems can be interpre...
# 1805  Cross language text classi?cation is an import...
# 1911  Recursive Neural Networks have recently obtain...
# 1917  We introduce a model for bidirectional retriev...
# 1961  To cope with the high level of ambiguity faced...
# 1980  We introduce a framework for unsupervised lear...
# 2047  We propose a method for automatically answerin...
# 2138  Dropout training, originally designed for deep...
# 2186  Semantic matching is of central importance to ...
# 2187  Recursive neural networks comprise a class of ...
# 2284  Recently, strong results have been demonstrate...
# 2393  Gibbs sampling on factor graphs is a widely us...
# 2412  We propose an approach for generating a sequen...
# 2516  In this paper, we propose a general smoothing ...
# 2544  We consider the problem of testing whether two...
# 2581  Teaching machines to read natural language doc...
# 2682  We introduce the value iteration network (VIN)...
# 2700  We propose a goal-driven web navigation as a b...
# 2770  Stochastic structured prediction under bandit ...
# 2864  The blind application of machine learning runs...
# 2897  Our method aims at reasoning over natural lang...
# 2900  A long-term goal of machine learning research ...
# 2920  Automatic translation from natural language de...
# 2931  Several mechanisms to focus attention of a neu...
# 3148  Recurrent neural networks (RNNs) have achieved...
# 3266  Cortical circuits exhibit intricate recurrent ...
# 3303  Recent work on fairness in machine learning ha...
# 3333  Deep Learning has revolutionized vision via co...
# 3445  Learning to communicate through interaction, r...
# 3543  Generative adversarial networks (GANs) have gr...
# 3640  Learning latent representations from long text...
# 3727  Robots will eventually be part of every househ...
# 3844  Computer vision has benefited from initializin...
# 3878  Categorical models are a natural fit for many ...
# 3883  Many efforts have been devoted to training gen...

# %% [markdown]
# ### 리스트와 사전

# %%
a = list(range(1000000))

# %% [markdown]
# ### 리스트에서 999999를 검색하는데 걸리는 시간 측정 리스트의 뒤로 갈 수록 검색이 오래 걸림

# %%
# %%time
a.index(999999)
# Out:
# CPU times: user 22.2 ms, sys: 1.53 ms, total: 23.7 ms
# Wall time: 26.1 ms
# 999999

# %%
b = dict(zip(a, a))

# %% [markdown]
# ### 검색 시간이 0에 가까움

# %%
# %%time
b[999999]
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.54 µs
# 999999

# %% [markdown]
# ### 인덱싱

# %%
from collections import defaultdict
index = defaultdict(set)

for row in df.itertuples():
    words = tokenize(row.abstract)
    for word in words:
        index[word].add(row.Index)

# %%
index['language']
# Out:
# {15,
#  27,
#  49,
#  51,
#  90,
#  161,
#  197,
#  269,
#  278,
#  347,
#  423,
#  450,
#  505,
#  542,
#  557,
#  626,
#  634,
#  747,
#  781,
#  846,
#  881,
#  1068,
#  1079,
#  1219,
#  1243,
#  1278,
#  1420,
#  1503,
#  1570,
#  1660,
#  1805,
#  1806,
#  1807,
#  1906,
#  1911,
#  1917,
#  1961,
#  1980,
#  2047,
#  2061,
#  2138,
#  2167,
#  2186,
#  2187,
#  2216,
#  2284,
#  2312,
#  2393,
#  2412,
#  2421,
#  2481,
#  2482,
#  2501,
#  2516,
#  2536,
#  2544,
#  2581,
#  2585,
#  2682,
#  2696,
#  2700,
#  2735,
#  2770,
#  2822,
#  2835,
#  2864,
#  2877,
#  2895,
#  2897,
#  2900,
#  2920,
#  2931,
#  2934,
#  3021,
#  3034,
#  3047,
#  3082,
#  3104,
#  3105,
#  3148,
#  3207,
#  3264,
#  3266,
#  3282,
#  3296,
#  3303,
#  3333,
#  3438,
#  3445,
#  3543,
#  3554,
#  3581,
#  3640,
#  3642,
#  3702,
#  3727,
#  3765,
#  3794,
#  3808,
#  3820,
#  3844,
#  3872,
#  3878,
#  3883,
#  3885}

# %%
# %%time
results = list(index['natural'] & index['language'])
# Out:
# CPU times: user 44 µs, sys: 0 ns, total: 44 µs
# Wall time: 49.6 µs

# %% [markdown]
# ## TF

# %%
from collections import Counter
idxs = list(index['natural'] & index['language'])
results = []
for row in df.iloc[idxs].itertuples():
    words = tokenize(row.abstract)
    cnt = Counter(words)
    tf = sum(cnt[w] for w in query)
    results.append((tf, row.Index))

# %% [markdown]
# ### 점수의 역순으로 정렬

# %%
idx = [i for _, i in sorted(results, reverse=True)]

# %% [markdown]
# ### 정렬된 문서 보기

# %%
df.iloc[idx]
# Out:
#       year                                              title  \
# 3445  2017  Emergence of Language with Multi-agent Games: ...
# 3148  2016  LightRNN: Memory and Computation-Efficient Rec...
# 1805  2013  A Novel Two-Step Method for Cross Language Rep...
# 2920  2016     Latent Attention For If-Then Program Synthesis
# 2900  2016                     Dialog-based Language Learning
# 2897  2016  Visual Question Answering with Question Repres...
# 2544  2015       Testing Closeness With Unequal Sized Samples
# 2412  2015  Expressing an Image Stream with a Sequence of ...
# 2186  2014  Convolutional Neural Network Architectures for...
# 1660  2013       A Deep Architecture for Matching Short Texts
# 1278  2012  Tensor Decomposition for Fast Parsing with Lat...
# 3878  2017  The power of absolute discounting: all-dimensi...
# 3543  2017        Adversarial Ranking for Language Generation
# 2700  2016              End-to-End Goal-Driven Web Navigation
# 2581  2015           Teaching Machines to Read and Comprehend
# 2187  2014  Deep Recursive Neural Networks for Composition...
# 1068  2011  Kernel Embeddings of Latent Tree Graphical Models
# 881   2011  Inverting Grice's Maxims to Learn Rules from N...
# 269   2008  Modeling the effects of memory on human online...
# 49    2007  Discriminative Keyword Selection Using Support...
# 3883  2017  Z-Forcing: Training Stochastic Recurrent Networks
# 3844  2017  Learned in Translation: Contextualized Word Ve...
# 3727  2017  Teaching Machines to Describe Images with Natu...
# 3640  2017  Deconvolutional Paragraph Representation Learning
# 3333  2017                   Self-Normalizing Neural Networks
# 3303  2017   Avoiding Discrimination through Causal Reasoning
# 3266  2017  Cortical microcircuits as gated-recurrent neur...
# 2931  2016               Can Active Memory Replace Attention?
# 2864  2016  Man is to Computer Programmer as Woman is to H...
# 2770  2016  Stochastic Structured Prediction under Bandit ...
# 2682  2016                           Value Iteration Networks
# 2516  2015  A Structural Smoothing Framework For Robust Gr...
# 2393  2015  Rapidly Mixing Gibbs Sampling for a Class of F...
# 2284  2015        Learning to Transduce with Unbounded Memory
# 2138  2014  Altitude Training: Strong Bounds for Single-La...
# 2047  2014  A Multi-World Approach to Question Answering a...
# 1980  2014  Conditional Random Field Autoencoders for Unsu...
# 1961  2014  Submodular meets Structured: Finding Diverse S...
# 1917  2014  Deep Fragment Embeddings for Bidirectional Ima...
# 1911  2014            Global Belief Recursive Neural Networks
# 1503  2013  Unsupervised Spectral Learning of Finite State...
# 1219  2012  Learned Prioritization for Trading Off Accurac...
# 1079  2011  Higher-Order Correlation Clustering for Image ...
# 846   2010      Probabilistic Deterministic Infinite Automata
# 557   2009                          Conditional Neural Fields
# 542   2009                  Rethinking LDA: Why Priors Matter
#
#                                                abstract
# 3445  Learning to communicate through interaction, r...
# 3148  Recurrent neural networks (RNNs) have achieved...
# 1805  Cross language text classi?cation is an import...
# 2920  Automatic translation from natural language de...
# 2900  A long-term goal of machine learning research ...
# 2897  Our method aims at reasoning over natural lang...
# 2544  We consider the problem of testing whether two...
# 2412  We propose an approach for generating a sequen...
# 2186  Semantic matching is of central importance to ...
# 1660  Many machine learning problems can be interpre...
# 1278  We describe an approach to speed-up inference ...
# 3878  Categorical models are a natural fit for many ...
# 3543  Generative adversarial networks (GANs) have gr...
# 2700  We propose a goal-driven web navigation as a b...
# 2581  Teaching machines to read natural language doc...
# 2187  Recursive neural networks comprise a class of ...
# 1068  Latent tree graphical models are natural tools...
# 881   We consider the problem of learning rules from...
# 269   Language comprehension in humans is significan...
# 49    Many tasks in speech processing involve classi...
# 3883  Many efforts have been devoted to training gen...
# 3844  Computer vision has benefited from initializin...
# 3727  Robots will eventually be part of every househ...
# 3640  Learning latent representations from long text...
# 3333  Deep Learning has revolutionized vision via co...
# 3303  Recent work on fairness in machine learning ha...
# 3266  Cortical circuits exhibit intricate recurrent ...
# 2931  Several mechanisms to focus attention of a neu...
# 2864  The blind application of machine learning runs...
# 2770  Stochastic structured prediction under bandit ...
# 2682  We introduce the value iteration network (VIN)...
# 2516  In this paper, we propose a general smoothing ...
# 2393  Gibbs sampling on factor graphs is a widely us...
# 2284  Recently, strong results have been demonstrate...
# 2138  Dropout training, originally designed for deep...
# 2047  We propose a method for automatically answerin...
# 1980  We introduce a framework for unsupervised lear...
# 1961  To cope with the high level of ambiguity faced...
# 1917  We introduce a model for bidirectional retriev...
# 1911  Recursive Neural Networks have recently obtain...
# 1503  Finite-State Transducers (FST) are a standard ...
# 1219  Users want natural language processing (NLP) s...
# 1079  For many of the state-of-the-art computer visi...
# 846   We propose a novel Bayesian nonparametric appr...
# 557   Conditional random fields (CRF) are quite succ...
# 542   Implementations of topic models typically use ...

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# ### 문서 빈도

# %%
{k: len(v) for k, v in index.items()}
# Out:
# {'it': 1326,
#  'is': 3158,
#  'known': 443,
#  'that': 3315,
#  'determinining': 1,
#  'whether': 84,
#  'dec': 4,
#  'pomdp': 14,
#  'namely': 72,
#  'cooperative': 16,
#  'partially': 78,
#  'observable': 49,
#  'stochastic': 434,
#  'game': 82,
#  'posg': 1,
#  'has': 932,
#  'strategy': 144,
#  'with': 2553,
#  'positive': 117,
#  'expected': 141,
#  'reward': 96,
#  'complete': 70,
#  'for': 3261,
#  'nexp': 1,
#  'was': 130,
#  'not': 870,
#  'until': 23,
#  'now': 36,
#  'how': 551,
#  'cooperation': 1,
#  'affected': 12,
#  'complexity': 372,
#  'we': 3766,
#  'show': 1762,
#  'competitive': 148,
#  'posgs': 2,
#  'the': 3903,
#  'of': 3875,
#  'determining': 32,
#  'one': 698,
#  'team': 6,
#  'class': 483,
#  'an': 2170,
#  'oracle': 72,
#  'np': 56,
#  'present': 797,
#  'first': 675,
#  'truly': 14,
#  'polynomial': 140,
#  'algorithm': 1471,
#  'learning': 1775,
#  'structure': 505,
#  'bounded': 109,
#  'treewidth': 12,
#  'junction': 5,
#  'trees': 78,
#  'attractive': 40,
#  'subclass': 15,
#  'probabilistic': 297,
#  'graphical': 172,
#  'models': 1071,
#  'permits': 16,
#  'both': 875,
#  'compact': 57,
#  'representation': 278,
#  'probability': 311,
#  'distributions': 338,
#  'and': 3784,
#  'efficient': 690,
#  'exact': 166,
#  'inference': 587,
#  'constant': 147,
#  'our': 2166,
#  'time': 807,
#  'sample': 369,
#  'provides': 309,
#  'strong': 221,
#  'theoretical': 502,
#  'guarantees': 319,
#  'in': 3614,
#  'terms': 306,
#  'kl': 30,
#  'divergence': 66,
#  'from': 1725,
#  'true': 150,
#  'distribution': 519,
#  'also': 956,
#  'lazy': 8,
#  'extension': 106,
#  'approach': 1036,
#  'leads': 177,
#  'to': 3730,
#  'very': 340,
#  'significant': 232,
#  'speed': 144,
#  'ups': 7,
#  'practice': 191,
#  'demonstrate': 842,
#  'viability': 4,
#  'method': 1092,
#  'empirically': 218,
#  'on': 2949,
#  'several': 526,
#  'real': 708,
#  'world': 382,
#  'datasets': 519,
#  'key': 229,
#  'new': 950,
#  'insights': 74,
#  'bounding': 32,
#  'conditional': 187,
#  'mutual': 47,
#  'information': 578,
#  'arbitrarily': 36,
#  'large': 794,
#  'sets': 287,
#  'random': 398,
#  'variables': 302,
#  'only': 672,
#  'number': 778,
#  'computations': 74,
#  'fixed': 165,
#  'size': 299,
#  'subsets': 40,
#  'when': 772,
#  'underlying': 255,
#  'can': 1949,
#  'be': 1826,
#  'approximated': 47,
#  'by': 2131,
#  'tree': 143,
#  'semi': 130,
#  'supervised': 229,
#  'inductive': 17,
#  'concerns': 11,
#  'learn': 438,
#  'decision': 226,
#  'rule': 91,
#  'data': 1630,
#  'set': 606,
#  'containing': 35,
#  'labeled': 101,
#  'unlabeled': 84,
#  'boosting': 50,
#  'algorithms': 995,
#  'have': 887,
#  'been': 614,
#  'extended': 79,
#  'various': 232,
#  'strategies': 93,
#  'knowledge': 230,
#  'however': 673,
#  'none': 9,
#  'them': 222,
#  'takes': 78,
#  'local': 308,
#  'smoothness': 50,
#  'constraints': 199,
#  'among': 171,
#  'into': 504,
#  'account': 113,
#  'during': 134,
#  'ensemble': 41,
#  'this': 2886,
#  'paper': 1368,
#  'introduce': 492,
#  'regularizer': 43,
#  'based': 1374,
#  'universal': 36,
#  'optimization': 612,
#  'framework': 661,
#  'margin': 94,
#  'cost': 265,
#  'functionals': 13,
#  'applicable': 74,
#  'existing': 539,
#  'improve': 249,
#  'their': 535,
#  'generalization': 217,
#  'up': 262,
#  'training': 538,
#  'comparative': 9,
#  'results': 1179,
#  'synthetic': 305,
#  'benchmark': 177,
#  'tasks': 462,
#  'effectiveness': 190,
#  'discuss': 70,
#  'relevant': 93,
#  'issues': 45,
#  'relate': 30,
#  'previous': 394,
#  'work': 608,
#  'under': 532,
#  'suitable': 79,
#  'assumptions': 193,
#  'primarily': 16,
#  'linearization': 3,
#  'simple': 456,
#  'perspicuous': 1,
#  'online': 279,
#  'bottleneck': 36,
#  'spiking': 61,
#  'neurons': 131,
#  'derived': 110,
#  'performs': 124,
#  'common': 205,
#  'as': 2149,
#  'well': 738,
#  'rather': 150,
#  'complex': 257,
#  'previously': 123,
#  'proposed': 791,
#  'cite': 33,
#  'klampfletal': 1,
#  '07b': 1,
#  'furthermore': 177,
#  'transparency': 1,
#  'makes': 137,
#  'analysis': 680,
#  'its': 694,
#  'convergence': 404,
#  'properties': 366,
#  'feasible': 40,
#  'variation': 60,
#  'sign': 14,
#  'changes': 70,
#  'theoretically': 112,
#  'founded': 3,
#  'performing': 75,
#  'principal': 65,
#  'component': 138,
#  'pca': 67,
#  'applying': 81,
#  'different': 515,
#  'components': 122,
#  'input': 285,
#  'extracted': 37,
#  'addition': 169,
#  'possible': 274,
#  'preferentially': 2,
#  'extract': 54,
#  'those': 167,
#  'incoming': 6,
#  'signals': 82,
#  'are': 2209,
#  'related': 224,
#  'or': 1040,
#  'some': 384,
#  'additional': 134,
#  'target': 149,
#  'signal': 137,
#  'y_t': 1,
#  'biological': 55,
#  'interpretation': 65,
#  'called': 249,
#  'relevance': 33,
#  'variable': 188,
#  'could': 96,
#  'represent': 117,
#  'proprioceptive': 2,
#  'feedback': 71,
#  'other': 514,
#  'sensory': 64,
#  'modalities': 18,
#  'top': 80,
#  'down': 49,
#  'natural': 314,
#  'viewing': 14,
#  'conditions': 201,
#  'human': 213,
#  'observers': 2,
#  'shift': 32,
#  'gaze': 6,
#  'allocate': 7,
#  'processing': 171,
#  'resources': 26,
#  'visual': 194,
#  'many': 655,
#  'computational': 409,
#  'aimed': 9,
#  'at': 743,
#  'predicting': 65,
#  'such': 1157,
#  'voluntary': 3,
#  'attentional': 12,
#  'shifts': 11,
#  'although': 125,
#  'importance': 83,
#  'high': 606,
#  'level': 213,
#  'stimulus': 61,
#  'higher': 133,
#  'order': 450,
#  'statistics': 170,
#  'semantics': 12,
#  'stands': 6,
#  'undisputed': 1,
#  'most': 464,
#  'low': 382,
#  'features': 406,
#  'alone': 28,
#  'study': 498,
#  'recorded': 43,
#  'eye': 9,
#  'movements': 21,
#  'while': 681,
#  'they': 364,
#  'viewed': 46,
#  'photographs': 2,
#  'scenes': 34,
#  'about': 276,
#  'two': 884,
#  'thirds': 1,
#  'stimuli': 67,
#  'contained': 6,
#  'least': 146,
#  'person': 19,
#  'combined': 77,
#  'model': 1494,
#  'face': 59,
#  'detection': 139,
#  'saliency': 13,
#  'clearly': 18,
#  'outperforms': 289,
#  'locations': 50,
#  'humans': 62,
#  'fixate': 1,
#  'reflected': 9,
#  'finding': 151,
#  'fact': 93,
#  'observes': 10,
#  'even': 350,
#  'instructed': 2,
#  'look': 22,
#  'anything': 4,
#  'particular': 398,
#  'over': 846,
#  '80': 8,
#  'within': 248,
#  'fixations': 6,
#  '500ms': 1,
#  'remarkably': 25,
#  'predictive': 117,
#  'performance': 910,
#  'images': 259,
#  'do': 222,
#  'contain': 33,
#  'faces': 30,
#  'impaired': 3,
#  'spurious': 7,
#  'detector': 17,
#  'responses': 80,
#  'which': 1949,
#  'suggestive': 3,
#  'bottom': 19,
#  'mechanism': 95,
#  'summary': 20,
#  'provide': 644,
#  'novel': 727,
#  'combines': 97,
#  'object': 214,
#  'case': 410,
#  'successfully': 91,
#  'predict': 110,
#  'allocation': 58,
#  'repositories': 4,
#  'source': 87,
#  'code': 85,
#  'create': 23,
#  'challenges': 71,
#  'opportunities': 8,
#  'statistical': 354,
#  'machine': 444,
#  'here': 282,
#  'develop': 447,
#  'infrastructure': 2,
#  'automated': 30,
#  'crawling': 3,
#  'parsing': 14,
#  'database': 32,
#  'storage': 29,
#  'open': 75,
#  'software': 23,
#  'allows': 382,
#  'us': 250,
#  'gather': 6,
#  'internet': 18,
#  'scale': 336,
#  'instance': 115,
#  'experiment': 52,
#  '632': 1,
#  'java': 1,
#  'projects': 10,
#  'sourceforge': 1,
#  'apache': 2,
#  'totaling': 1,
#  '38': 2,
#  'million': 44,
#  'lines': 13,
#  '250': 2,
#  'developers': 4,
#  'analyses': 40,
#  'reveal': 49,
#  'robust': 208,
#  'power': 156,
#  'law': 33,
#  'behavior': 175,
#  'package': 6,
#  'sloc': 1,
#  'call': 113,
#  'then': 489,
#  'apply': 270,
#  'unsupervised': 161,
#  'author': 5,
#  'topic': 100,
#  'automatically': 117,
#  'discover': 52,
#  'topics': 48,
#  'embedded': 47,
#  'word': 76,
#  'serving': 5,
#  'convenient': 15,
#  'program': 74,
#  'function': 733,
#  'developer': 2,
#  'activities': 24,
#  'these': 1030,
#  'theoretic': 88,
#  'basis': 77,
#  'quantifying': 11,
#  'analyzing': 54,
#  'similarity': 123,
#  'competence': 2,
#  'scattering': 3,
#  'document': 64,
#  'tangling': 1,
#  'direct': 65,
#  'applications': 489,
#  'engineering': 26,
#  'finally': 227,
#  'combining': 79,
#  'textual': 9,
#  'content': 46,
#  'structural': 80,
#  'captured': 25,
#  'coderank': 1,
#  'able': 236,
#  'significantly': 325,
#  'retrieval': 60,
#  'increasing': 73,
#  'auc': 9,
#  'metric': 126,
#  '86': 5,
#  'roughly': 16,
#  '10': 82,
#  '30': 12,
#  'better': 408,
#  'than': 842,
#  'approaches': 438,
#  'text': 108,
#  'construct': 117,
#  'biologically': 25,
#  'motivated': 112,
#  'differential': 60,
#  'neural': 563,
#  'hemodynamic': 2,
#  'activity': 103,
#  'observed': 201,
#  'blood': 4,
#  'oxygen': 1,
#  'dependent': 151,
#  'bold': 1,
#  'functional': 86,
#  'magnetic': 18,
#  'resonance': 17,
#  'imaging': 52,
#  'fmri': 29,
#  'poses': 24,
#  'difficult': 170,
#  'parameter': 280,
#  'estimation': 425,
#  'problem': 1408,
#  'due': 221,
#  'nonlinearity': 9,
#  'system': 228,
#  'computationally': 210,
#  'space': 470,
#  'adapt': 54,
#  'particle': 28,
#  'filter': 51,
#  'smoother': 4,
#  'task': 472,
#  'practical': 219,
#  'used': 719,
#  'tackle': 49,
#  'difficulties': 21,
#  'including': 307,
#  'use': 645,
#  'sparse': 384,
#  'matrices': 134,
#  'parallelisation': 2,
#  'tractability': 14,
#  'application': 167,
#  'effective': 229,
#  'connectivity': 48,
#  'independent': 207,
#  'ica': 19,
#  'powerful': 130,
#  'decouple': 4,
#  'consider': 473,
#  'temporal': 141,
#  'correlations': 62,
#  'but': 655,
#  'moments': 34,
#  'amplitude': 9,
#  'moreover': 184,
#  'require': 195,
#  'preprocessing': 12,
#  'whitening': 8,
#  'so': 230,
#  'remove': 27,
#  'second': 254,
#  'interested': 35,
#  'understanding': 109,
#  'responsible': 10,
#  'solving': 182,
#  'exploits': 45,
#  'delayed': 8,
#  'detecting': 35,
#  'joint': 152,
#  'variations': 37,
#  'firing': 33,
#  'rates': 169,
#  'pre': 64,
#  'postsynaptic': 6,
#  'similar': 235,
#  'rate': 308,
#  'hebbian': 11,
#  'discriminative': 116,
#  'clustering': 203,
#  'recently': 316,
#  'simultaneous': 28,
#  'subspace': 86,
#  'selection': 229,
#  'via': 268,
#  'linear': 675,
#  'discriminant': 15,
#  'lda': 35,
#  'empirical': 430,
#  'shown': 242,
#  'favorable': 33,
#  'comparison': 87,
#  'popular': 223,
#  'inherent': 56,
#  'relationship': 63,
#  'between': 774,
#  'understood': 55,
#  'iterative': 86,
#  'nature': 79,
#  'equivalent': 60,
#  'kernel': 278,
#  'means': 109,
#  'specific': 223,
#  'gram': 14,
#  'matrix': 386,
#  'procedure': 235,
#  'equivalence': 28,
#  'propose': 1232,
#  'diskmeans': 1,
#  'automatic': 59,
#  'nonlinear': 131,
#  'using': 1103,
#  'kernels': 92,
#  'convex': 439,
#  'specified': 60,
#  'incorporated': 20,
#  'formulation': 174,
#  'connection': 67,
#  'analyzed': 24,
#  'presented': 89,
#  'theories': 21,
#  'evaluated': 49,
#  'through': 311,
#  'experiments': 704,
#  'collection': 75,
#  'epoch': 5,
#  'greedy': 107,
#  'multi': 379,
#  'armed': 60,
#  'bandits': 44,
#  'side': 48,
#  'following': 68,
#  'no': 251,
#  'horizon': 38,
#  'necessary': 76,
#  'regret': 191,
#  'incurred': 12,
#  'controlled': 34,
#  'bound': 351,
#  'hypothesis': 93,
#  'scales': 123,
#  'sometimes': 35,
#  'much': 264,
#  'term': 136,
#  'standard': 388,
#  'approximation': 352,
#  'computing': 161,
#  'map': 126,
#  'log': 242,
#  'partition': 75,
#  'arbitrary': 175,
#  'exponential': 137,
#  'family': 206,
#  'represented': 88,
#  'finite': 174,
#  'valued': 53,
#  'pair': 59,
#  'wise': 66,
#  'markov': 262,
#  'field': 125,
#  'mrf': 18,
#  'say': 8,
#  'decomposing': 12,
#  'appropriately': 19,
#  'chosen': 66,
#  'small': 303,
#  'estimates': 194,
#  'locally': 60,
#  'each': 671,
#  'producing': 29,
#  'good': 207,
#  'global': 192,
#  'solution': 275,
#  'prove': 344,
#  'approximate': 326,
#  'accuracy': 395,
#  'excludes': 2,
#  'sized': 22,
#  'graph': 265,
#  'minor': 3,
#  'degree': 67,
#  'all': 529,
#  'planar': 8,
#  'graphs': 137,
#  'examples': 180,
#  'running': 78,
#  'theta': 25,
#  'nodes': 110,
#  'excluded': 2,
#  'uses': 199,
#  'decomposition': 110,
#  'scheme': 172,
#  'klein': 1,
#  'plotkin': 1,
#  'rao': 13,
#  '1993': 3,
#  'general': 524,
#  'works': 91,
#  'any': 470,
#  'quantifiable': 3,
#  'guarantee': 87,
#  'depends': 84,
#  'dealing': 26,
#  'location': 51,
#  'change': 87,
#  'points': 210,
#  'dimensional': 418,
#  'piecewise': 32,
#  'white': 11,
#  'noise': 259,
#  'consists': 67,
#  'reframing': 1,
#  'context': 188,
#  'penalized': 37,
#  'squares': 71,
#  'criterion': 61,
#  'l1': 43,
#  'type': 125,
#  'penalty': 53,
#  'purpose': 63,
#  'appropriate': 85,
#  'asymptotic': 107,
#  'consistent': 141,
#  'estimators': 104,
#  'explain': 58,
#  'implement': 95,
#  'lar': 2,
#  'reduced': 70,
#  'version': 93,
#  'dynamic': 134,
#  'programming': 126,
#  'leverages': 30,
#  'millions': 35,
#  'clicks': 5,
#  'received': 42,
#  'web': 43,
#  'search': 187,
#  'engines': 10,
#  'ranking': 67,
#  'functions': 503,
#  'available': 205,
#  'judgments': 8,
#  'after': 103,
#  'initial': 77,
#  'phase': 56,
#  'paired': 7,
#  'click': 6,
#  'score': 56,
#  'documents': 46,
#  'judged': 4,
#  'predictions': 152,
#  'evaluate': 182,
#  'engine': 14,
#  'formalization': 6,
#  'confidence': 73,
#  'evaluation': 118,
#  'discounted': 16,
#  'cumulative': 31,
#  'gain': 50,
#  'dcg': 2,
#  'comparisons': 51,
#  'made': 91,
#  'across': 201,
#  'contrasts': 10,
#  'methods': 1059,
#  'judgements': 1,
#  'same': 296,
#  'query': 69,
#  'identify': 135,
#  'ranked': 10,
#  'lists': 11,
#  '82': 6,
#  '94': 2,
#  'sponsored': 4,
#  'financial': 11,
#  'backbone': 2,
#  'enough': 50,
#  'algorithmic': 76,
#  'give': 191,
#  'guide': 21,
#  'judge': 3,
#  'em': 134,
#  'dimensionality': 114,
#  'reduction': 169,
#  'manifold': 67,
#  'modeled': 60,
#  'projections': 43,
#  'reals': 2,
#  'belonging': 11,
#  'unknown': 200,
#  'euclidean': 54,
#  'intrinsic': 51,
#  'dimension': 171,
#  'id': 2,
#  'estimated': 120,
#  'rigorously': 18,
#  'estimate': 237,
#  'cases': 204,
#  'required': 138,
#  'logarithmic': 59,
#  'meaning': 18,
#  'll': 11,
#  'handle': 84,
#  'situations': 43,
#  'smallest': 12,
#  'projection': 64,
#  'perform': 232,
#  'particularly': 88,
#  'distributed': 138,
#  'sensing': 53,
#  'systems': 227,
#  'potential': 116,
#  'savings': 17,
#  'acquisition': 19,
#  'transmission': 16,
#  'costs': 41,
#  'variant': 109,
#  'adapts': 19,
#  'language': 105,
#  'forms': 41,
#  'phoneme': 5,
#  'sequences': 87,
#  'undergo': 3,
#  'edits': 2,
#  'along': 79,
#  'branches': 2,
#  'phylogenetic': 4,
#  'advantages': 110,
#  'classical': 145,
#  'robustness': 76,
#  'corpus': 20,
#  'explore': 112,
#  'consequences': 16,
#  'schemes': 79,
#  'defining': 35,
#  'phonological': 1,
#  'evaluating': 38,
#  'reconstruction': 81,
#  'ancient': 1,
#  'romance': 1,
#  'languages': 17,
#  'result': 313,
#  'inferring': 52,
#  'modern': 68,
#  'generalized': 138,
#  'support': 157,
#  'inferences': 25,
#  'linguistic': 11,
#  'phylogenies': 1,
#  'provably': 96,
#  'processes': 195,
#  'mdps': 31,
#  'continuous': 214,
#  'state': 867,
#  'action': 126,
#  'spaces': 118,
#  'setting': 401,
#  'specifically': 146,
#  'take': 109,
#  'special': 155,
#  'regression': 317,
#  'possibly': 52,
#  'kernalized': 1,
#  'linearly': 87,
#  'parameterized': 31,
#  'dynamics': 167,
#  'builds': 37,
#  'kearns': 4,
#  'singh': 2,
#  'restricted': 103,
#  'classes': 146,
#  'address': 229,
#  'adaptive': 127,
#  'sensor': 31,
#  'control': 155,
#  'resource': 27,
#  'constrained': 101,
#  'networks': 543,
#  'focus': 124,
#  'meteorological': 2,
#  'network': 492,
#  'comprising': 4,
#  'radars': 1,
#  'sector': 1,
#  'scanning': 6,
#  'always': 56,
#  '360': 2,
#  'degrees': 17,
#  'compare': 139,
#  'three': 195,
#  'sit': 1,
#  'spin': 3,
#  'scans': 2,
#  'limited': 162,
#  'lookahead': 6,
#  'additionally': 53,
#  'environmental': 8,
#  'epochs': 6,
#  'future': 76,
#  'predicted': 42,
#  'kalman': 17,
#  'filters': 42,
#  'making': 188,
#  'full': 133,
#  'states': 115,
#  'casting': 10,
#  'process': 447,
#  'reinforcement': 159,
#  'optimal': 589,
#  'scan': 7,
#  'main': 188,
#  'benefits': 88,
#  'there': 298,
#  'multiple': 377,
#  'phenomena': 33,
#  'environment': 91,
#  'maximum': 216,
#  'radius': 10,
#  'phenomenon': 30,
#  'sufficiently': 45,
#  'smaller': 84,
#  'trade': 71,
#  'off': 105,
#  'average': 127,
#  'quality': 188,
#  'scanned': 2,
#  'before': 49,
#  'rescanned': 1,
#  'message': 60,
#  'passing': 57,
#  'approximating': 45,
#  'max': 73,
#  'product': 100,
#  'unlike': 121,
#  'converges': 88,
#  'proven': 49,
#  'find': 251,
#  'settings': 195,
#  'block': 77,
#  'coordinate': 81,
#  'descent': 224,
#  'dual': 89,
#  'lp': 27,
#  'relaxation': 86,
#  'does': 230,
#  'tunable': 4,
#  'parameters': 415,
#  'step': 224,
#  'weights': 132,
#  'describe': 177,
#  'cluster': 93,
#  'potentials': 30,
#  'tested': 39,
#  'problems': 792,
#  'compares': 22,
#  'favorably': 24,
#  'vector': 208,
#  'machines': 79,
#  'svms': 42,
#  'suffer': 39,
#  'widely': 139,
#  'recognized': 9,
#  'scalability': 76,
#  'memory': 152,
#  'developed': 99,
#  'parallel': 105,
#  'svm': 72,
#  'psvm': 1,
#  'reduces': 70,
#  'row': 22,
#  'factorization': 79,
#  'loads': 3,
#  'essential': 49,
#  'computation': 190,
#  'let': 14,
#  'denote': 6,
#  'instances': 121,
#  'requirement': 27,
#  'mo': 1,
#  'improves': 154,
#  'studies': 152,
#  '500': 8,
#  'computers': 5,
#  'shows': 172,
#  'becoming': 11,
#  'increasingly': 46,
#  'important': 296,
#  'missing': 77,
#  'elements': 59,
#  'assume': 109,
#  'entire': 54,
#  'single': 325,
#  'drawn': 60,
#  'variate': 12,
#  'suggest': 122,
#  'mvtm': 1,
#  'generalizes': 61,
#  'range': 170,
#  'encourage': 18,
#  'non': 657,
#  'conjugacy': 6,
#  'prior': 291,
#  'make': 213,
#  'mode': 28,
#  'mean': 176,
#  'posterior': 194,
#  'sequentially': 33,
#  'minimizes': 47,
#  'upper': 159,
#  'likelihood': 227,
#  'scalable': 127,
#  'toy': 15,
#  'eachmovie': 1,
#  'dataset': 238,
#  'movement': 17,
#  'built': 32,
#  'sub': 102,
#  'blocks': 33,
#  'motion': 77,
#  'primitives': 11,
#  'desirable': 60,
#  'robotic': 18,
#  'analyse': 12,
#  'handwriting': 11,
#  'timings': 2,
#  'shape': 49,
#  'timing': 27,
#  'done': 45,
#  'factorial': 14,
#  'hmm': 16,
#  'allowing': 88,
#  'primitive': 8,
#  'spikes': 28,
#  'corresponding': 157,
#  'activations': 21,
#  'modelled': 12,
#  'architectures': 91,
#  'coupling': 26,
#  'produce': 95,
#  ...}

# %% [markdown]
# ### 전체 문서 수

# %%
N, _ = df.shape

# %% [markdown]
# ### 역문서빈도(inverse document frequency)

# %%
import numpy as np
idf = {k: np.log(N / len(v)) for k, v in index.items()}

idxs = list(index['natural'] & index['language'])
results = []

for row in df.iloc[idxs].itertuples():
    words = tokenize(row.abstract)
    cnt = Counter(words)
    tfidf = sum(cnt[w] * idf[w] for w in query)
    results.append((tfidf, row.Index))

idx = [i for _, i in sorted(results, reverse=True)]

# %% [markdown]
# ## BM25

# %%
# !pip install rank_bm25 kiwipiepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Collecting kiwipiepy
#   Downloading kiwipiepy-0.15.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from rank_bm25) (1.22.4)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting kiwipiepy-model~=0.15
#   Downloading kiwipiepy_model-0.15.0.tar.gz (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 28.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: kiwipiepy-model
#   Building wheel for kiwipiepy-model (setup.py) ... done
#   Created wheel for kiwipiepy-model: filename=kiwipiepy_model-0.15.0-py3-none-any.whl size=30602642 sha256=e95132aa37316a470d5ea635bbbd175d7fc23c44ff8b0e80bc865df2fe6d8446
#   Stored in directory: /root/.cache/pip/wheels/9e/34/31/a1682c8249bf2ba89a29498d62c35c08ceb116537b4530d93e
# Successfully built kiwipiepy-model
# Installing collected packages: kiwipiepy-model, dataclasses, rank_bm25, kiwipiepy
# Successfully installed dataclasses-0.6 kiwipiepy-0.15.0 kiwipiepy-model-0.15.0 rank_bm25-0.2.2

# %%
import pandas as pd
books = pd.read_csv('/content/drive/Othercomputers/내 노트북/study/06_TextAnalytics/data/science_books.csv')

# %%
from kiwipiepy import Kiwi
kiwi = Kiwi()


def tokenize(sent):
    for token in kiwi.tokenize(sent):
        if token.tag in {'NNG', 'NNP', 'SL', 'VV', 'VA'}:
            yield token.form, token.tag

# %%
tokenized_corpus = []
for title in books.제목:
    tokenized_corpus.append(list(tokenize(title)))

# %%
from rank_bm25 import BM25Okapi
bm25 = BM25Okapi(tokenized_corpus)

# %%
import pandas as pd
idf_table = pd.DataFrame(bm25.idf.items(), columns=['token', 'idf'])
idf_table.sort_values('idf')
# Out:
#             token       idf
# 24      (과학, NNG)  1.590378
# 169     (수학, NNG)  2.076635
# 9      (이야기, NNG)  2.226424
# 17      (세상, NNG)  2.396806
# 31      (양장, NNG)  2.396806
# ...           ...       ...
# 1249  (아이디어, NNG)  6.501790
# 1248     (보듬, VV)  6.501790
# 1247    (이웃, NNG)  6.501790
# 1621  (스타일링, NNG)  6.501790
# 2389   (트리즈, NNG)  6.501790
#
# [2390 rows x 2 columns]

# %%
list(tokenize('다정한 것이 살아남는다'))
# Out:
# [('다정', 'NNG'), ('살아남', 'VV')]

# %%
query = list(tokenize('다정한 것이 살아남는다'))
bm25.get_top_n(query, books.제목, n=5)
# Out:
# ['다정한 것이 살아남는다 : 친화력으로 세상을 바꾸는 인류의 진화에 관하여(10만부 기념 스페셜 에디션, 저자 친필 사인 인쇄본)',
#  '낙타는 왜 사막으로 갔을까 : 살아남은 동물들의 비밀',
#  '무엇이 우리를 다정하게 만드는가 : 타인을 도우려 하는 인간 심리의 뇌과학적 비밀(양장)',
#  '우주에서 기다릴게 : 한국 첫 우주인이 펼치는 다정한 호기심의 기록',
#  '다정한 물리학 : 거대한 우주와 물질의 기원을 탐구하고 싶을 때']

# %% [markdown]
# ### 임베딩을 이용한 검색

# %%
# !pip install sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 49.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (0.15.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.9 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.11.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (16.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 63.9 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=54029372c4852df38684bb02ad5ce0eb6c519f454471f5378e9cd6a044862485
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, sentence-transformers
# Successfully installed huggingface-hub-0.13.4 sentence-transformers-2.2.2 sentencepiece-0.1.98 tokenizers-0.13.3 transformers-4.28.1

# %%
from sentence_transformers import SentenceTransformer
sbert = SentenceTransformer(
    'snunlp/KR-SBERT-V40K-klueNLI-augSTS')
# Out:
# Downloading (…)635b2/.gitattributes:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)3f97e635b2/README.md:   0%|          | 0.00/4.02k [00:00<?, ?B/s]
# Downloading (…)97e635b2/config.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/467M [00:00<?, ?B/s]

# %%
from sklearn.metrics.pairwise import cosine_similarity
emb = sbert.encode(books.제목)

query_emb = sbert.encode(['다정한 것이 살아남는다'])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
# %%time
sims = cosine_similarity(query_emb, emb)
ids = np.argsort(-sims[0])[:5]
# Out:
# CPU times: user 10.9 ms, sys: 7.13 ms, total: 18 ms
# Wall time: 2.19 ms

# %%
books.iloc[ids]
# Out:
#                                                     제목
# 322           다정함의 과학 : 친절, 신뢰, 공감 속에 숨어 있는 건강과 행복의 비밀
# 6    다정한 것이 살아남는다 : 친화력으로 세상을 바꾸는 인류의 진화에 관하여(10만부 ...
# 618                  모든 것은 그 자리에 : 첫사랑부터 마지막 이야기까지(양장)
# 392  이토록 다정한 기술 : 지구와 이웃을 보듬는 아이디어(〈희망의 이유〉 사쉐 증정 (...
# 111  무엇이 우리를 다정하게 만드는가 : 타인을 도우려 하는 인간 심리의 뇌과학적 비밀(양장)

# %% [markdown]
# ### nmslib

# %%
# !pip install nmslib
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: nmslib in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: psutil in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from nmslib) (5.9.0)
# Requirement already satisfied: pybind11<2.6.2 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from nmslib) (2.6.1)
# Requirement already satisfied: numpy>=1.10.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from nmslib) (1.23.5)

# %%
import nmslib
index = nmslib.init()
index.addDataPointBatch(emb)
index.createIndex()

# %%
# %%time
ids, dist = index.knnQuery(query_emb, k=5)
# Out:
# CPU times: user 231 µs, sys: 67 µs, total: 298 µs
# Wall time: 217 µs

# %%
books.iloc[ids]
# Out:
#                                                     제목
# 322           다정함의 과학 : 친절, 신뢰, 공감 속에 숨어 있는 건강과 행복의 비밀
# 6    다정한 것이 살아남는다 : 친화력으로 세상을 바꾸는 인류의 진화에 관하여(10만부 ...
# 618                  모든 것은 그 자리에 : 첫사랑부터 마지막 이야기까지(양장)
# 392  이토록 다정한 기술 : 지구와 이웃을 보듬는 아이디어(〈희망의 이유〉 사쉐 증정 (...
# 111  무엇이 우리를 다정하게 만드는가 : 타인을 도우려 하는 인간 심리의 뇌과학적 비밀(양장)

# %% [markdown]
# ### chroma

# %%
# !pip install chromadb
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: chromadb in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (0.3.21)
# Requirement already satisfied: sentence-transformers>=2.2.2 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from chromadb) (2.2.2)
# Requirement already satisfied: posthog>=2.4.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from chromadb) (2.5.0)
# Requirement already satisfied: duckdb>=0.7.1 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from chromadb) (0.7.1)
# Requirement already satisfied: clickhouse-connect>=0.5.7 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from chromadb) (0.5.20)
# Requirement already satisfied: requests>=2.28 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from chromadb) (2.28.2)
# Requirement already satisfied: numpy>=1.21.6 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from chromadb) (1.23.5)
# Requirement already satisfied: pydantic>=1.9 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from chromadb) (1.10.7)
# Requirement already satisfied: pandas>=1.3 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from chromadb) (2.0.0)
# Requirement already satisfied: fastapi>=0.85.1 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from chromadb) (0.95.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: hnswlib>=0.7 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from chromadb) (0.7.0)
# Requirement already satisfied: urllib3>=1.26 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from clickhouse-connect>=0.5.7->chromadb) (1.26.15)
# Requirement already satisfied: zstandard in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from clickhouse-connect>=0.5.7->chromadb) (0.20.0)
# Requirement already satisfied: lz4 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from clickhouse-connect>=0.5.7->chromadb) (4.3.2)
# Requirement already satisfied: pytz in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from clickhouse-connect>=0.5.7->chromadb) (2023.3)
# Requirement already satisfied: certifi in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from clickhouse-connect>=0.5.7->chromadb) (2022.12.7)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from fastapi>=0.85.1->chromadb) (0.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from pandas>=1.3->chromadb) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from pandas>=1.3->chromadb) (2023.3)
# Requirement already satisfied: monotonic>=1.5 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: six>=1.5 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from sentence-transformers>=2.2.2->chromadb) (4.27.4)
# Requirement already satisfied: torch>=1.6.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from sentence-transformers>=2.2.2->chromadb) (2.0.0)
# Requirement already satisfied: scikit-learn in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from sentence-transformers>=2.2.2->chromadb) (1.2.2)
# Requirement already satisfied: nltk in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from sentence-transformers>=2.2.2->chromadb) (3.8.1)
# Requirement already satisfied: sentencepiece in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from sentence-transformers>=2.2.2->chromadb) (0.1.97)
# Requirement already satisfied: tqdm in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from sentence-transformers>=2.2.2->chromadb) (4.65.0)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from sentence-transformers>=2.2.2->chromadb) (0.13.4)
# Requirement already satisfied: scipy in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from sentence-transformers>=2.2.2->chromadb) (1.10.1)
# Requirement already satisfied: torchvision in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from sentence-transformers>=2.2.2->chromadb) (0.15.1)
# Requirement already satisfied: click>=7.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.5.0)
# Requirement already satisfied: websockets>=10.4 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.17.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: filelock in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb) (3.11.0)
# Requirement already satisfied: packaging>=20.9 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb) (23.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from starlette<0.27.0,>=0.26.1->fastapi>=0.85.1->chromadb) (3.6.2)
# Requirement already satisfied: networkx in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (3.0)
# Requirement already satisfied: sympy in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (1.11.1)
# Requirement already satisfied: jinja2 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (3.1.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb) (2023.3.23)
# Requirement already satisfied: joblib in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from nltk->sentence-transformers>=2.2.2->chromadb) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from scikit-learn->sentence-transformers>=2.2.2->chromadb) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from torchvision->sentence-transformers>=2.2.2->chromadb) (9.4.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.27.0,>=0.26.1->fastapi>=0.85.1->chromadb) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/mond/anaconda3/envs/text_analysis/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (1.3.0)

# %%
import chromadb

# %%
client = chromadb.Client()
# Out:
# Using embedded DuckDB without persistence: data will be transient

# %%
collection = client.create_collection(
    name="science_books", 
    embedding_function=sbert.encode)

# %%
metadatas = books.제목.map(lambda x: {'length': len(x)}).tolist()
ids = books.index.map(str).tolist()
collection.add(
    documents=books.제목.tolist(),
    metadatas=metadatas,
    ids=ids
)

# %%
results = collection.query(
    query_texts=["다정한 것이 살아남는다"],
    n_results=5
)

# %%
# %%time
results = collection.query(
    query_embeddings=[query_emb[0]],
    n_results=5
)
# Out:
# CPU times: user 7.94 ms, sys: 4.65 ms, total: 12.6 ms
# Wall time: 1.8 ms

# %%
query_emb.shape
# Out:
# (1, 768)

# %%
results
# Out:
# {'ids': [['6', '322', '392', '111', '313']],
#  'embeddings': None,
#  'documents': [['다정한 것이 살아남는다 : 친화력으로 세상을 바꾸는 인류의 진화에 관하여(10만부 기념 스페셜 에디션, 저자 친필 사인 인쇄본)',
#    '다정함의 과학 : 친절, 신뢰, 공감 속에 숨어 있는 건강과 행복의 비밀',
#    '이토록 다정한 기술 : 지구와 이웃을 보듬는 아이디어(〈희망의 이유〉 사쉐 증정 (포인트 차감))',
#    '무엇이 우리를 다정하게 만드는가 : 타인을 도우려 하는 인간 심리의 뇌과학적 비밀(양장)',
#    'ADHD 2.0 : 산만하고 변덕스러운 ‘나’를 뛰어난 ‘창조자’로 바꾸는 특별한 여정!(포함 건강취미분야 2만원↑ 데일리 알약케이스 증정(택1, 포인트 차감))']],
#  'metadatas': [[{'length': 71},
#    {'length': 40},
#    {'length': 54},
#    {'length': 49},
#    {'length': 90}]],
#  'distances': [[305.2730407714844,
#    332.41082763671875,
#    351.195068359375,
#    361.7748718261719,
#    384.9884033203125]]}

# %%
results = collection.query(
    query_texts=["다정한 것이 살아남는다"],
    n_results=5,
    where={"length": {'$lt': 75}},
    where_document={"$contains":"다정"}
)

# %%
results
# Out:
# {'ids': [['6', '322', '392', '111', '105']],
#  'embeddings': None,
#  'documents': [['다정한 것이 살아남는다 : 친화력으로 세상을 바꾸는 인류의 진화에 관하여(10만부 기념 스페셜 에디션, 저자 친필 사인 인쇄본)',
#    '다정함의 과학 : 친절, 신뢰, 공감 속에 숨어 있는 건강과 행복의 비밀',
#    '이토록 다정한 기술 : 지구와 이웃을 보듬는 아이디어(〈희망의 이유〉 사쉐 증정 (포인트 차감))',
#    '무엇이 우리를 다정하게 만드는가 : 타인을 도우려 하는 인간 심리의 뇌과학적 비밀(양장)',
#    '다정한 물리학 : 거대한 우주와 물질의 기원을 탐구하고 싶을 때']],
#  'metadatas': [[{'length': 71},
#    {'length': 40},
#    {'length': 54},
#    {'length': 49},
#    {'length': 35}]],
#  'distances': [[305.2730407714844,
#    332.41082763671875,
#    351.195068359375,
#    361.7748718261719,
#    475.3113708496094]]}

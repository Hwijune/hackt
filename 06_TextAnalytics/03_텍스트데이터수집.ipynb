# %% [markdown]
# ## STT(openai whisper)

# %%
pip install -U openai-whisper kiwipiepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached openai_whisper-20230314-py3-none-any.whl
# ...
#   Using cached kiwipiepy-0.15.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.8 MB)
# ...
#   Using cached ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# ...
#   Using cached triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# ...
#   Using cached tiktoken-0.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
# ...
#   Using cached lit-16.0.0-py3-none-any.whl
# ...
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# ...
#   Using cached kiwipiepy_model-0.15.0-py3-none-any.whl
# ...

# %%
import unicodedata

import tqdm
import whisper
from kiwipiepy import Kiwi

# %%
model = whisper.load_model("medium")
kiwi = Kiwi()
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:16<00:00, 92.8MiB/s]

# %%
import glob
filelist = glob.glob('/content/drive/Othercomputers/내 노트북/study/06_TextAnalytics/data/*.mp3')

# %%
filelist
# Out:
# ['/content/drive/Othercomputers/내 노트북/study/06_TextAnalytics/data/공기어네트워크.mp3']

# %%
for filename in filelist:
    print("filename :", filename)
    result = model.transcribe(filename, language='ko') # 음성 인식
    print("result :", filename)
    sents = kiwi.split_into_sents(result['text'])  # 문장 단위로 자르기
    print("sents :", filename)
    text = '\n\n'.join(sent.text for sent in sents) # 하나로 합치기
    print(text)
    txt_name = filename.replace('.mp3', '.txt') # 저장할 파일명
    txt_name = unicodedata.normalize('NFC', txt_name) # NFC로 노말라이즈
    with open(txt_name, "w") as f:
        f.write(text)
# Out:
# filename : /content/drive/Othercomputers/내 노트북/study/06_TextAnalytics/data/공기어네트워크.mp3
# result : /content/drive/Othercomputers/내 노트북/study/06_TextAnalytics/data/공기어네트워크.mp3
# sents : /content/drive/Othercomputers/내 노트북/study/06_TextAnalytics/data/공기어네트워크.mp3
# 공기어넷터크는 공자는 공동할 때 공짜입니다.
#
# 함께 이런 뜻이죠.
#
# 그 다음에 기는 일어난다
#
# 이런 뜻이에요.
#
# 함께 일어난다
#
# 이런 뜻이고 그래서 어떤 말과 말이 같이 나오는 경우 우리 그런 경우 있죠.
#
# 누구를 보니까 예를 들어서 철수가 있는데 맨날 보면 철수는 영이랑 같이 있어요.
#
# 너희는 맨날 붙어 다니냐?
#
# 그러면 우리 아니라고, 아무 사이로.
#
# 사람도 보면 맨날 붙어 다니는 사람이 있고 그 다음에 단어도 보면 맨날 붙어 다니는 단어들이 있어요.
#
# 맨날 붙어 다니는 단어들을 꼭 맨날 붙어 달라고 할 필요는 없는데 같이 붙어서 나오면 공기어라고 해요.
#
# 그래서 공기어를 넷터크 형태로 분석하는 것을 공기어 넷터크 분석 이렇게 말합니다.
#
# 넷터크 분석이라는 것은 넷터크는 기본적으로 점이 있고 그 다음에 점과 점이 선으로 연결된 이런 구조를 넷터크라고 불러요.

# %% [markdown]
# ## 웹크롤링

# %%
import requests
url = 'https://ko.wikipedia.org/wiki/HTML'
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
# !pip install cssselect
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip3 install lxml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from lxml import html

# %%
root = html.fromstring(res.text)

# %%
ts = root.cssselect('title')

# %%
ts
# Out:
# [<Element title at 0x7f72810ab090>]

# %%
ts[0].text
# Out:
# 'HTML - 위키백과, 우리 모두의 백과사전'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

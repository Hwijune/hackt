# %%
import numpy as np
from scipy import linalg as la

# %%
#L2 norm, euclidean norm
a = np.array([2,3])
np.sqrt(np.sum(np.dot(a, a)))
# Out:
# 3.605551275463989

# %%
la.norm(a)
# Out:
# 3.605551275463989

# %%
#aT = [1, 2, 3, 4]에 대하여 a / ||a|| 값 구하기
#벡터 표준화
a = np.array([1,2,3,4])
res = a / la.norm(a)

# %%
# a / ||a||에 대하여 || a / || a || ||값 구하기 #시험
# normalization
# 어떤 벡타가 들어와도 결과는 1
la.norm(res)
# Out:
# 0.9999999999999999

# %%
#벡터 노름의 성질
a = np.array([-1, 2, 3])
b = np.array([1, -2, 4])

#스칼라 곱
beta = 0.5
la.norm(beta * a) == np.abs(beta) * la.norm(a)
# Out:
# True

# %%
#삼각형의 한 변의 길이는 다른 두변의 길이 합보다 작다.
la.norm(a+b) <= la.norm(a) + la.norm(b)
# Out:
# True

# %%
la.norm(a) >= 0
# Out:
# True

# %%
#코사인 theta 구하기
#데이터 구성
a = np.array([1,3])
b = np.array([3,1])

cos_theta_rad = np.dot(a,b) / (la.norm(a)*la.norm(b))

#theta_rad값 구하기
theta_rad = np.arccos(cos_theta_rad)

# 각도 전환: pi radian = 180 degree
theta = theta_rad * (180/np.pi)
[cos_theta_rad, theta]
# Out:
# [0.5999999999999999, 53.13010235415599]

# %%
#코사인 theta 구하기
#데이터 구성
a = np.array([0,1])
b = np.array([1,0])

cos_theta_rad = np.dot(a,b) / (la.norm(a)*la.norm(b))

#theta_rad값 구하기
theta_rad = np.arccos(cos_theta_rad)

# 각도 전환: pi radian = 180 degree
theta = theta_rad * (180/np.pi)
[cos_theta_rad, theta]
# Out:
# [0.0, 90.0]

# %%
#코사인 theta 구하기
#데이터 구성
a = np.array([-1,-1])
b = np.array([1,0])

cos_theta_rad = np.dot(a,b) / (la.norm(a)*la.norm(b))

#theta_rad값 구하기
theta_rad = np.arccos(cos_theta_rad)

# 각도 전환: pi radian = 180 degree
theta = theta_rad * (180/np.pi)
[cos_theta_rad, theta]
# Out:
# [-0.7071067811865475, 135.0]

# %% [markdown]
# 1) 1 2 3 𝑇 , 1 1 1 𝑇 , −1 − 1 − 1 𝑇 로 구성된 벡터는 서로 독립인지를 확인 해보자.

# %% [markdown]
# 2) 2차원 즉, 평면에서의 기저를 찾아보자.

# %% [markdown]
# 3) 𝑎 1 =
# 0
# 0
# 1
# ,𝑎 2 =
# 1
# 2
# 1
# 1
# 0
# ,𝑎 3 =
# 1
# 2
# 1
# −1
# 0
# 가 서로 직교정규 벡터임을 확인해보자.

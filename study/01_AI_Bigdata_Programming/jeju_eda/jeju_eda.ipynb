# %%
import os
path = os.getcwd()
print(path)
# Out:
# /home/hwi/study/code_test/study/01_AI_Bigdata_Programming

# %%
#!pip install pandas_profiling
import pandas_profiling as pp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='whitegrid', font_scale=1.5)
sns.set_palette('Set2', n_colors=10)
plt.rc('font', family='malgun gothic')
plt.rc('axes', unicode_minus=False)

# %%
df1 = pd.read_csv('/home/hwi/study/code_test/study/01_AI_Bigdata_Programming/jeju_eda/df_card.csv')
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253155 entries, 0 to 253154
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   분석년월        253155 non-null  int64
#  1   상호명         253155 non-null  object
#  2   시군구명        253155 non-null  object
#  3   행정동명        253155 non-null  object
#  4   지역명         253155 non-null  object
#  5   중분류명        253155 non-null  object
#  6   소분류명        253155 non-null  object
#  7   제주도민매출금액비율  253155 non-null  float64
#  8   제주도민매출수비율   253155 non-null  float64
#  9   외지인매출금액비율   253155 non-null  float64
#  10  외지인매출수비율    253155 non-null  float64
#  11  전체매출금액비율    253155 non-null  float64
#  12  전체매출수비율     253155 non-null  float64
#  13  변화율         226646 non-null  float64
#  14  순위수         226646 non-null  float64
#  15  격자ID        253155 non-null  object
# dtypes: float64(8), int64(1), object(7)
# memory usage: 30.9+ MB
# ...

# %%
#  #   Column      Non-Null Count   Dtype  
# ---  ------      --------------   -----  
#  0   분석년월        253155 non-null  int64  
#  1   상호명         253155 non-null  object 
#  2   시군구명        253155 non-null  object 
#  3   행정동명        253155 non-null  object 
#  4   지역명         253155 non-null  object 
#  5   중분류명        253155 non-null  object 
#  6   소분류명        253155 non-null  object 
#  7   제주도민매출금액비율  253155 non-null  float64
#  8   제주도민매출수비율   253155 non-null  float64
#  9   외지인매출금액비율   253155 non-null  float64
#  10  외지인매출수비율    253155 non-null  float64
#  11  전체매출금액비율    253155 non-null  float64
#  12  전체매출수비율     253155 non-null  float64
#  13  변화율         226646 non-null  float64
#  14  순위수         226646 non-null  float64
#  15  격자ID        253155 non-null  object 

df.rename(columns={'분석년월':'Date', 
'상호명':'Store_name', 
'시군구명': 'si_gune_gu', 
'행정동명': 'Dong', 
'지역명': 'loc', 
'중분류명': 'cate1', 
'소분류명': 'cate2',
'제주도민매출금액비율': 'jeju_person_sales',
'제주도민매출수비율': 'jeju_person_sales_num',
'외지인매출금액비율': 'other_person_sales',
'외지인매출수비율': 'other_person_sales_num',
'전체매출금액비율': 'tot_sales',
'전체매출수비율': 'tot_sales_num',
'변화율': 'change',
'순위수': 'ranking',
'격자ID': 'ID'
})
# Out:
#           Date       Store_name si_gune_gu Dong      loc  cate1    cate2  \
# 0       202101   한국맥도날드(유)제주노형점        제주시  노형동  제주시 동지역  패스트푸드      햄버거
# 1       202101        버거킹제주이마트점        제주시  노형동  제주시 동지역  패스트푸드      햄버거
# 2       202101  투썸플레이스 제주노형오거리점        제주시  노형동  제주시 동지역     음료       커피
# 3       202101      뚜레쥬르 노형오거리점        제주시  노형동  제주시 동지역     간식     베이커리
# 4       202101     에이바우트커피아이파크점        제주시  노형동  제주시 동지역     음료       커피
# ...        ...              ...        ...  ...      ...    ...      ...
# 253150  202207            남문회센타        제주시  화북동  제주시 동지역     한식        회
# 253151  202207            황금성반점        제주시  화북동  제주시 동지역  아시아음식       중식
# 253152  202207           남문두루치기        제주시  화북동  제주시 동지역     한식  단품요리 전문
# 253153  202207             갈비정식        제주시  화북동  제주시 동지역     한식       갈비
# 253154  202207   불타는여고24시떡볶이삼화점        제주시  화북동  제주시 동지역     간식       분식
#
#         jeju_person_sales  jeju_person_sales_num  other_person_sales  \
# ...

# %%
df2 = pd.read_csv('/home/hwi/study/code_test/study/01_AI_Bigdata_Programming/jeju_eda/df_call.csv')
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   접수일자       990 non-null    int64
#  1   언어구분명      990 non-null    object
#  2   상담대분류명     990 non-null    object
#  3   상담중분류명     990 non-null    object
#  4   상담소분류명     990 non-null    object
#  5   상담키워드1순위명  934 non-null    object
#  6   상담키워드2순위명  780 non-null    object
#  7   상담키워드3순위명  606 non-null    object
#  8   상담키워드4순위명  454 non-null    object
#  9   상담키워드5순위명  325 non-null    object
#  10  상담유형명      990 non-null    object
#  11  여행목적명      990 non-null    object
#  12  경로명        990 non-null    object
#  13  고객성향명      990 non-null    object
#  14  채널구분명      990 non-null    object
#  15  통화구분명      990 non-null    object
#  16  상태명        990 non-null    object
#  17  수정일자       990 non-null    int64
# dtypes: int64(2), object(16)
# memory usage: 139.3+ KB
# ...

# %%
report = df1.profile_report(title='제주카드')
report.to_file('jeju_eda/report_card.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /home/hwi/.local/lib/python3.8/site-packages/scipy/stats/_stats_py.py:5215: RuntimeWarning: overflow encountered in long_scalars
#   (2 * xtie * ytie) / m + x0 * y0 / (9 * m * (size - 2)))
# /home/hwi/.local/lib/python3.8/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   plt.savefig(
# /home/hwi/.local/lib/python3.8/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from current font.
#   plt.savefig(
# /home/hwi/.local/lib/python3.8/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from current font.
#   plt.savefig(
# /home/hwi/.local/lib/python3.8/site-packages/pandas_profiling/visualisation/utils.py:73: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   plt.savefig(
# ...
